# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %%
chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get("https://filkom.ub.ac.id/")

# %%
data = driver.find_elements(by=By.CLASS_NAME, value="premium-blog-entry-title")

# %%
data[0].text

# %%
data[0].find_element(by=By.TAG_NAME, value="a").click()

# %%
for d in data:
    value = d.find_element(by=By.TAG_NAME, value="a")
    print(value.text)
    print("========")

# %%
driver.get("https://github.com/")

# %%
data_github = driver.find_elements(
    by=By.CLASS_NAME,
    value="lp-SectionBlock-content",
)

# %%
for d in data_github:
    print(d.find_element(by=By.TAG_NAME, value="span").text)

# %%
span_data = data_github.find_element(by=By.TAG_NAME, value="span")

# %%
span_data.text

# %%
span_data.find_element(by=By.TAG_NAME, value="span")
